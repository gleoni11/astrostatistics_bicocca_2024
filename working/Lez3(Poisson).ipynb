# %%
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt

morti = np.array([0,1,2,3,4])
gruppi = np.array([109,65,22,3,1])

#nel caso di conteggi la prob è data dalla freq dell'evento
tot = np.sum(gruppi)
freq=gruppi/tot

plt.scatter(morti, freq)

for mu in [0.1,0.3, 0.5, 0.9, 1.2, 1.5]:
    pdf = scipy.stats.poisson(mu).pmf(deaths)
    plt.plot(deaths, pdf, label='mu='+str(mu))

plt.legend()
plt.show()

# %%
best = scipy.stats.poisson(0.5).pmf(morti)
plt.plot(morti, best, label="best fit")
plt.scatter(deaths, freq, label="dati")
plt.legend()
plt.show()
